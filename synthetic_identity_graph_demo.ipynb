# %% [markdown]
# # Synthetic Identity Graph Risk Demo\nLoad sample identity profiles and graph edges.

# %%
import pandas as pd\nprofiles = pd.read_csv('../data/sample/sample_synthetic_identity_profiles.csv')\nprofiles.head()

# %%
edges = pd.read_csv('../data/sample/sample_identity_graph_edges.csv')\nedges.head()
